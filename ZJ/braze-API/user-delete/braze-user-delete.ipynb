# %%
# Live B2B
import csv
from datetime import datetime
import requests
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Get the API key from the environment variables
API_KEY = os.getenv("BRAZE_B2B_DELETE_LIVE_API_KEY")

# Prepare API request
def track_user(external_id):
    url = f"https://rest.fra-01.braze.eu/users/delete"
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {API_KEY}"
    }
    payload = {
        "external_ids": external_id
    }
    response = requests.post(url, headers=headers, json=payload)
    return response.json()

user_to_delete = [ 
    ''
]

# Batching user IDs and loop through multiple requests
def main():
    batch_size = 50
    total_users = len(user_to_delete)
    num_batches = (total_users + batch_size - 1) // batch_size

    for i in range(num_batches):
        start_index = i * batch_size
        end_index = min((i + 1) * batch_size, total_users)
        batch_users = user_to_delete[start_index:end_index]
        response = track_user(batch_users)
        print(f"Batch {i+1}/{num_batches} - Status: {response['message']}")

if __name__ == "__main__":
    main()
# Out:
# Batch 1/1 - Status: success

# %%
# Staging B2B
import csv
from datetime import datetime
import requests
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Get the API key from the environment variables
API_KEY = os.getenv("BRAZE_B2B_DELETE_STAGING_API_KEY")

# Prepare API request
def track_user(external_id):
    url = f"https://rest.fra-01.braze.eu/users/delete"
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {API_KEY}"
    }
    payload = {
        "external_ids": external_id
    }
    response = requests.post(url, headers=headers, json=payload)
    return response.json()

user_to_delete = [ 
    ''
]

# Batching user IDs and loop through multiple requests
def main():
    batch_size = 50
    total_users = len(user_to_delete)
    num_batches = (total_users + batch_size - 1) // batch_size

    for i in range(num_batches):
        start_index = i * batch_size
        end_index = min((i + 1) * batch_size, total_users)
        batch_users = user_to_delete[start_index:end_index]
        response = track_user(batch_users)
        print(f"Batch {i+1}/{num_batches} - Status: {response['message']}")

if __name__ == "__main__":
    main()

# %%
# Live B2C
import csv
from datetime import datetime
import requests
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Get the API key from the environment variables
API_KEY = os.getenv("BRAZE_B2C_DELETE_LIVE_API_KEY")

# Prepare API request
def track_user(external_id):
    url = f"https://rest.fra-01.braze.eu/users/delete"
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {API_KEY}"
    }
    payload = {
        "external_ids": external_id
    }
    response = requests.post(url, headers=headers, json=payload)
    return response.json()

user_to_delete = [ 
    ''
]

# Batching user IDs and loop through multiple requests
def main():
    batch_size = 50
    total_users = len(user_to_delete)
    num_batches = (total_users + batch_size - 1) // batch_size

    for i in range(num_batches):
        start_index = i * batch_size
        end_index = min((i + 1) * batch_size, total_users)
        batch_users = user_to_delete[start_index:end_index]
        response = track_user(batch_users)
        print(f"Batch {i+1}/{num_batches} - Status: {response['message']}")

if __name__ == "__main__":
    main()

# %%
# Staging B2C
import csv
from datetime import datetime
import requests
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Get the API key from the environment variables
API_KEY = os.getenv("BRAZE_B2C_DELETE_STAGING_API_KEY")

# Prepare API request
def track_user(external_id):
    url = f"https://rest.fra-01.braze.eu/users/delete"
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {API_KEY}"
    }
    payload = {
        "external_ids": external_id
    }
    response = requests.post(url, headers=headers, json=payload)
    return response.json()

user_to_delete = [ 
    ''
]

# Batching user IDs and loop through multiple requests
def main():
    batch_size = 50
    total_users = len(user_to_delete)
    num_batches = (total_users + batch_size - 1) // batch_size

    for i in range(num_batches):
        start_index = i * batch_size
        end_index = min((i + 1) * batch_size, total_users)
        batch_users = user_to_delete[start_index:end_index]
        response = track_user(batch_users)
        print(f"Batch {i+1}/{num_batches} - Status: {response['message']}")

if __name__ == "__main__":
    main()
